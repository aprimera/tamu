# %% [markdown]
# <a href="https://colab.research.google.com/github/aprimera/tamu/blob/main/TAMU_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA Example

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = "https://github.com/orkahub/PEG_Python/raw/master/Data/Sample%20Petrophysics.xlsx"

# %%
df = pd.read_excel(file)

# %%
df.head(10)
# Out:
#        Well     Zones  Top (m)  Base (m)  Porosity     Sw       NTG
# 0    DUM008  MONTREAL  1195.00   1205.50     0.140  0.720  0.588571
# 1    DUM009  MONTREAL  1252.00   1268.50     0.130  0.400  0.374545
# 2    DUM023  MONTREAL  1358.00   1370.00     0.080  0.680  0.515000
# 3    DUM034  MONTREAL  1280.00   1295.00     0.140  0.440  0.412000
# 4    DUM038  MONTREAL  1353.00   1365.00     0.100  0.530  0.515000
# 5    DUM044  MONTREAL  1141.00   1158.50     0.040  0.670  0.353143
# 6    DUM045  MONTREAL  1292.00   1304.00     0.100  0.550  0.515000
# 7    DUM049  MONTREAL  1287.00   1306.00     0.090  0.560  0.325263
# 8    DUM050  MONTREAL  1255.00   1270.00     0.130  0.780  0.412000
# 9  DUM0506D  MONTREAL  1307.55   1320.65     0.211  0.304  0.471756

# %%
df.tail(5)
# Out:
#        Well    Zones  Top (m)  Base (m)  Porosity    Sw       NTG
# 439  DUM390  HOUSTON   1138.0    1146.5      0.07  0.79  0.727059
# 440  DUM391  HOUSTON   1183.5    1198.5      0.11  0.77  0.412000
# 441  DUM392  HOUSTON   1131.0    1147.5      0.11  0.75  0.374545
# 442  DUM394  HOUSTON    993.0    1009.0      0.20  0.50  0.386250
# 443  DUM396  HOUSTON   1114.5    1133.0      0.18  0.70  0.334054

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
df_sum = df.describe()
df_sum['Porosity']
# Out:
# count    444.000000
# mean       0.105086
# std        0.054896
# min        0.000000
# 25%        0.060000
# 50%        0.100000
# 75%        0.150000
# max        0.240000
# Name: Porosity, dtype: float64

# %%
df_sum.loc['50%']
# Out:
# Top (m)     1142.500000
# Base (m)    1155.500000
# Porosity       0.100000
# Sw             0.680000
# NTG            0.441429
# Name: 50%, dtype: float64

# %%
# Let's go back to the original data frame
# Let's plot the Porosity vs Sw for the zone Houston

# %%
df['Zones'].unique()
# Out:
# array(['MONTREAL', 'LIMA', 'LONDON', 'HOUSTON'], dtype=object)

# %%
df_houston = df[df['Zones']=='HOUSTON']

# %%
df_houston.describe()
# Out:
#            Top (m)     Base (m)    Porosity          Sw         NTG
# count   143.000000   143.000000  143.000000  143.000000  143.000000
# mean   1105.454545  1120.512098    0.147154    0.568762    0.450427
# std      50.695594    49.997283    0.042927    0.175882    0.169690
# min     993.000000  1002.000000    0.040000    0.140000    0.280909
# 25%    1060.750000  1076.250000    0.120000    0.450000    0.343333
# 50%    1116.000000  1133.000000    0.150000    0.570000    0.386250
# 75%    1145.500000  1159.000000    0.178000    0.690000    0.484892
# max    1200.000000  1209.000000    0.240000    0.980000    1.000000

# %%
plt.scatter(df_houston['Porosity'], df_houston['Sw'])

# %%
# Let's visualize with Seaborn
sns.pairplot(df)

# %%
df['HiPhi'] = (df['Base (m)']-df['Top (m)'])*df['Porosity']

# %%
df.head(5)
# Out:
#      Well     Zones  Top (m)  Base (m)  Porosity    Sw       NTG  HiPhi
# 0  DUM008  MONTREAL   1195.0    1205.5      0.14  0.72  0.588571  1.470
# 1  DUM009  MONTREAL   1252.0    1268.5      0.13  0.40  0.374545  2.145
# 2  DUM023  MONTREAL   1358.0    1370.0      0.08  0.68  0.515000  0.960
# 3  DUM034  MONTREAL   1280.0    1295.0      0.14  0.44  0.412000  2.100
# 4  DUM038  MONTREAL   1353.0    1365.0      0.10  0.53  0.515000  1.200

# %%
sns.pairplot(df, hue='Zones')

# %%
sns.boxplot(df_houston['NTG'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
